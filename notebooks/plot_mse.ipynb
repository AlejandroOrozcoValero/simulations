# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
Jext32_paths = [
    "/home/alejandro/Proyectos/simulations/results/mse_analysis/results/16-mse-J_EE_J_IE-Jext32.pkl",
    "/home/alejandro/Proyectos/simulations/results/mse_analysis/results/16-mse-J_EI_J_II-Jext32.pkl",
    "/home/alejandro/Proyectos/simulations/results/mse_analysis/results/16-mse-tau_syn_E-Jext32.pkl",
    "/home/alejandro/Proyectos/simulations/results/mse_analysis/results/16-mse-tau_syn_I-Jext32.pkl",
    "/home/alejandro/Proyectos/simulations/results/mse_analysis/results/16-mse-J_ext.pkl",
]

Jext2989_paths = [
    "/home/alejandro/Proyectos/simulations/results/mse_analysis/results/16-mse-J_EE_J_IE-Jext2989.pkl",
    "/home/alejandro/Proyectos/simulations/results/mse_analysis/results/16-mse-J_EI_J_II-Jext2989.pkl",
    "/home/alejandro/Proyectos/simulations/results/mse_analysis/results/16-mse-tau_syn_E-Jext2989.pkl",
    "/home/alejandro/Proyectos/simulations/results/mse_analysis/results/16-mse-tau_syn_I-Jext2989.pkl",
    "/home/alejandro/Proyectos/simulations/results/mse_analysis/results/16-mse-J_ext.pkl",
]

# %% [markdown]
# ## Results for J_ext = 32 nA

# %%
for result in Jext32_paths:
    df = pd.read_pickle(result)
    display(df)
# Out:
#    Parameter     Configuration  \
# 0  J_EE_J_IE  (1.9237, 2.4444)
# 1  J_EE_J_IE  (1.6178, 2.0556)
# 2  J_EE_J_IE  (2.5359, 3.2222)
# 3  J_EE_J_IE     (0.3935, 0.5)
# 4  J_EE_J_IE  (0.6996, 0.8889)
# 5  J_EE_J_IE  (2.8419, 3.6111)
# 6  J_EE_J_IE  (1.3117, 1.6667)
# 7  J_EE_J_IE  (2.2298, 2.8333)
# 8  J_EE_J_IE      (3.148, 4.0)
# 9  J_EE_J_IE  (1.0056, 1.2778)
#
#                                            MSE_curve  \
# 0  [0.9267036588445295, 1.7904472600635075, 2.329...
# 1  [0.9559680669184323, 1.846446148047183, 2.3759...
# 2  [0.8784877930486138, 1.689768861976975, 2.2222...
# 3  [0.9575017443223176, 1.8478476934451546, 2.362...
# 4  [0.965161724376342, 1.8655576659169095, 2.3743...
# 5  [0.8466236604354743, 1.6133937860741503, 2.140...
# 6  [0.9597306605056901, 1.857585890735133, 2.3818...
# 7  [0.901457376688879, 1.7404238352592933, 2.2792...
# 8  [0.8067765041609037, 1.4970767274111805, 2.021...
# 9  [0.9681258394757146, 1.8711099109532505, 2.394...
#
# ...

# %%
def process_file(path):
    df = pd.read_pickle(path)
    result = pd.DataFrame({
        'ID': df['Parameter'],
        'Group': df['Configuration'],
        'AUC_mean': df['AUC_mean'],
        'AUC_std': df['AUC_std'],
        'm1_mean': df['m1'],
        'm1_std': 0,
        'm2_mean': df['m2'],
        'm2_std': 0,
    })
    return result


def process_all_files(paths):
    dfs = [process_file(path) for path in paths]
    return pd.concat(dfs, ignore_index=True)

# %%
df_jext32 = process_all_files(Jext32_paths)
df_jext32
# Out:
#            ID                Group   AUC_mean   AUC_std   m1_mean  m1_std  \
# 0   J_EE_J_IE     (1.9237, 2.4444)  52.806701  0.640105  0.485023       0
# 1   J_EE_J_IE     (1.6178, 2.0556)  53.243033  0.518489  0.489152       0
# 2   J_EE_J_IE     (2.5359, 3.2222)  51.771379  0.273014  0.477067       0
# 3   J_EE_J_IE        (0.3935, 0.5)  52.924978  0.317526  0.456288       0
# 4   J_EE_J_IE     (0.6996, 0.8889)  53.335432  0.534537  0.468389       0
# 5   J_EE_J_IE     (2.8419, 3.6111)  51.210308  0.367552  0.473988       0
# 6   J_EE_J_IE     (1.3117, 1.6667)  53.302128  0.305119  0.484064       0
# 7   J_EE_J_IE     (2.2298, 2.8333)  52.042874  0.426723  0.486924       0
# 8   J_EE_J_IE         (3.148, 4.0)  49.969895  0.508978  0.462646       0
# 9   J_EE_J_IE     (1.0056, 1.2778)  53.576997  0.238903  0.474665       0
# 10  J_EI_J_II   (-22.6667, -8.024)  52.657549  0.778275  0.484536       0
# 11  J_EI_J_II      (-14.0, -4.956)  49.108680  0.183467  0.478735       0
# ...

# %%
def plot_results(df):
    features = ['AUC', 'm1', 'm2']
    params = df['ID'].unique()
    n_params = len(params)

    fig, axes = plt.subplots(len(features), n_params, figsize=(5 * n_params, 4 * len(features)), squeeze=False)

    for col, param in enumerate(params):
        param_df = df[df['ID'] == param].copy()
        # Ordenar por valor absoluto del Group (soporta tuplas y escalares)
        param_df['_sort_key'] = param_df['Group'].apply(
            lambda g: tuple(abs(v) for v in g) if isinstance(g, tuple) else abs(g)
        )
        param_df = param_df.sort_values('_sort_key')
        x = range(len(param_df))
        labels = [str(g) for g in param_df['Group']]

        for row, feat in enumerate(features):
            ax = axes[row, col]
            mean = param_df[f'{feat}_mean']
            std = param_df[f'{feat}_std']

            ax.plot(list(x), mean.values, marker='o')
            if std.any():
                ax.fill_between(list(x), (mean - std).values, (mean + std).values, alpha=0.3)
            ax.set_xticks(list(x))
            ax.set_xticklabels(labels, rotation=45, ha='right', fontsize=8)

            if col == 0:
                ax.set_ylabel(feat)
            if row == 0:
                ax.set_title(param)

    fig.tight_layout()
    return fig

# %%
fig_jext32 = plot_results(df_jext32)

# %%
df_jext2989 = process_all_files(Jext2989_paths)
df_jext2989
# Out:
#            ID                Group   AUC_mean   AUC_std   m1_mean  m1_std  \
# 0   J_EE_J_IE        (0.3935, 0.5)  53.887600  0.380457  0.440318       0
# 1   J_EE_J_IE     (0.6996, 0.8889)  54.417531  0.491604  0.445715       0
# 2   J_EE_J_IE     (1.9237, 2.4444)  55.573712  0.339938  0.469533       0
# 3   J_EE_J_IE         (3.148, 4.0)  54.638441  0.364971  0.468065       0
# 4   J_EE_J_IE     (2.8419, 3.6111)  54.416598  0.499376  0.467350       0
# 5   J_EE_J_IE     (1.6178, 2.0556)  55.301413  0.271276  0.464505       0
# 6   J_EE_J_IE     (2.5359, 3.2222)  54.828880  0.359311  0.465825       0
# 7   J_EE_J_IE     (1.0056, 1.2778)  55.077236  0.461254  0.457086       0
# 8   J_EE_J_IE     (1.3117, 1.6667)  55.420300  0.303083  0.461820       0
# 9   J_EE_J_IE     (2.2298, 2.8333)  55.005240  0.403754  0.468281       0
# 10  J_EI_J_II      (-14.0, -4.956)  53.093847  0.622167  0.450960       0
# 11  J_EI_J_II    (-5.3333, -1.888)  46.599330  0.307453  0.402663       0
# ...

# %%
fig_jext2989 = plot_results(df_jext2989)
