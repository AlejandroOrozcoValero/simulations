# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
Jext32_paths = [
    "/home/alejandro/Proyectos/simulations/results/fei_analysis/results/18-fei_dfa-J_EE_J_IE-Jext32.pkl",
    "/home/alejandro/Proyectos/simulations/results/fei_analysis/results/18-fei_dfa-J_EI_J_II-Jext32.pkl",
    "/home/alejandro/Proyectos/simulations/results/fei_analysis/results/18-fei_dfa-tau_syn_E-Jext32.pkl",
    "/home/alejandro/Proyectos/simulations/results/fei_analysis/results/18-fei_dfa-tau_syn_I-Jext32.pkl",
    "/home/alejandro/Proyectos/simulations/results/fei_analysis/results/18-fei_dfa-J_ext.pkl",
]

Jext2989_paths = [
    "/home/alejandro/Proyectos/simulations/results/fei_analysis/results/18-fei_dfa-J_EE_J_IE-Jext2989.pkl",
    "/home/alejandro/Proyectos/simulations/results/fei_analysis/results/18-fei_dfa-J_EI_J_II-Jext2989.pkl",
    "/home/alejandro/Proyectos/simulations/results/fei_analysis/results/18-fei_dfa-tau_syn_E-Jext2989.pkl",
    "/home/alejandro/Proyectos/simulations/results/fei_analysis/results/18-fei_dfa-tau_syn_I-Jext2989.pkl",
    "/home/alejandro/Proyectos/simulations/results/fei_analysis/results/18-fei_dfa-J_ext.pkl",
]

# %% [markdown]
# ## Results for J_ext = 32 nA

# %%
for result in Jext32_paths:
    df = pd.read_pickle(result)
    display(df)
# Out:
#            ID  Trial             Group       DFA       fEI   fEI_raw  \
# 0   J_EE_J_IE      0  (1.9237, 2.4444)  0.535131       NaN       NaN
# 1   J_EE_J_IE      1  (1.9237, 2.4444)  0.437300       NaN       NaN
# 2   J_EE_J_IE      2  (1.9237, 2.4444)  0.610501  0.446078  0.601239
# 3   J_EE_J_IE      3  (1.9237, 2.4444)  0.544991       NaN       NaN
# 4   J_EE_J_IE      4  (1.9237, 2.4444)  0.394481       NaN       NaN
# 5   J_EE_J_IE      5  (1.9237, 2.4444)  0.564025       NaN       NaN
# 6   J_EE_J_IE      0  (1.6178, 2.0556)  0.644598  1.447580  1.447580
# 7   J_EE_J_IE      1  (1.6178, 2.0556)  0.375921       NaN       NaN
# 8   J_EE_J_IE      2  (1.6178, 2.0556)  0.608470  1.879319  1.879319
# 9   J_EE_J_IE      3  (1.6178, 2.0556)  0.188293       NaN       NaN
# 10  J_EE_J_IE      4  (1.6178, 2.0556)  0.361811       NaN       NaN
# 11  J_EE_J_IE      5  (1.6178, 2.0556)  0.353363       NaN       NaN
# 12  J_EE_J_IE      0  (2.5359, 3.2222)  0.597921       NaN       NaN
# ...

# %%
def process_file(path):
    df = pd.read_pickle(path)
    agg = df.groupby('Group', sort=False).agg(
        ID=('ID', 'first'),
        DFA_mean=('DFA', 'mean'),
        DFA_std=('DFA', 'std'),
        fEI_mean=('fEI', 'mean'),
        fEI_std=('fEI', 'std'),
        fEI_raw_mean=('fEI_raw', 'mean'),
        fEI_raw_std=('fEI_raw', 'std'),
    ).reset_index()
    return agg


def process_all_files(paths):
    dfs = [process_file(path) for path in paths]
    return pd.concat(dfs, ignore_index=True)

# %%
df_jext32 = process_all_files(Jext32_paths)
df_jext32
# Out:
#                   Group         ID  DFA_mean   DFA_std  fEI_mean   fEI_std  \
# 0      (1.9237, 2.4444)  J_EE_J_IE  0.514405  0.081717  0.446078       NaN
# 1      (1.6178, 2.0556)  J_EE_J_IE  0.422076  0.172857  1.663449  0.305286
# 2      (2.5359, 3.2222)  J_EE_J_IE  0.512942  0.091650       NaN       NaN
# 3         (0.3935, 0.5)  J_EE_J_IE  0.551986  0.154548  1.222035  0.986708
# 4      (0.6996, 0.8889)  J_EE_J_IE  0.465625  0.080789       NaN       NaN
# 5      (2.8419, 3.6111)  J_EE_J_IE  0.499469  0.197681  0.925056       NaN
# 6      (1.3117, 1.6667)  J_EE_J_IE  0.574646  0.110138  1.296635  0.589602
# 7      (2.2298, 2.8333)  J_EE_J_IE  0.529264  0.176741  1.426919  0.346884
# 8          (3.148, 4.0)  J_EE_J_IE  0.468102  0.090131  1.335898       NaN
# 9      (1.0056, 1.2778)  J_EE_J_IE  0.539175  0.282643  1.135678  0.417191
# 10   (-22.6667, -8.024)  J_EI_J_II  0.420098  0.091890       NaN       NaN
# ...

# %%
def plot_results(df):
    features = ['DFA', 'fEI', 'fEI_raw']
    params = df['ID'].unique()
    n_params = len(params)

    fig, axes = plt.subplots(len(features), n_params, figsize=(5 * n_params, 4 * len(features)), squeeze=False)

    for col, param in enumerate(params):
        param_df = df[df['ID'] == param].copy()
        param_df['_sort_key'] = param_df['Group'].apply(
            lambda g: tuple(abs(v) for v in g) if isinstance(g, tuple) else abs(g)
        )
        param_df = param_df.sort_values('_sort_key')
        x = range(len(param_df))
        labels = [str(g) for g in param_df['Group']]

        for row, feat in enumerate(features):
            ax = axes[row, col]
            mean = param_df[f'{feat}_mean']
            std = param_df[f'{feat}_std']

            ax.plot(list(x), mean.values, marker='o')
            ax.fill_between(list(x), (mean - std).values, (mean + std).values, alpha=0.3)
            ax.set_xticks(list(x))
            ax.set_xticklabels(labels, rotation=45, ha='right', fontsize=8)

            if col == 0:
                ax.set_ylabel(feat)
            if row == 0:
                ax.set_title(param)

    fig.tight_layout()
    return fig

# %%
fig_jext32 = plot_results(df_jext32)

# %%
df_jext2989 = process_all_files(Jext2989_paths)
df_jext2989
# Out:
#                   Group         ID  DFA_mean   DFA_std  fEI_mean   fEI_std  \
# 0         (0.3935, 0.5)  J_EE_J_IE  0.476987  0.129118  1.161478       NaN
# 1      (0.6996, 0.8889)  J_EE_J_IE  0.480088  0.143175  0.550057       NaN
# 2      (1.9237, 2.4444)  J_EE_J_IE  0.414611  0.080577       NaN       NaN
# 3          (3.148, 4.0)  J_EE_J_IE  0.547470  0.065343  0.284391       NaN
# 4      (2.8419, 3.6111)  J_EE_J_IE  0.463044  0.110130       NaN       NaN
# 5      (1.6178, 2.0556)  J_EE_J_IE  0.515812  0.138536  1.287544  0.761526
# 6      (2.5359, 3.2222)  J_EE_J_IE  0.502494  0.108477  1.191061       NaN
# 7      (1.0056, 1.2778)  J_EE_J_IE  0.558396  0.131182  1.005022  0.178774
# 8      (1.3117, 1.6667)  J_EE_J_IE  0.423111  0.136374       NaN       NaN
# 9      (2.2298, 2.8333)  J_EE_J_IE  0.574887  0.114020  0.799808  0.291887
# 10      (-14.0, -4.956)  J_EI_J_II  0.470675  0.038214       NaN       NaN
# ...

# %%
fig_jext2989 = plot_results(df_jext2989)
