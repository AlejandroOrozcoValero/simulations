# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
Jext32_paths = [
    "/home/alejandro/Proyectos/simulations/results/nonlinear_analysis/results/17-nonlinear-J_EE_J_IE-Jext32.pkl",
    "/home/alejandro/Proyectos/simulations/results/nonlinear_analysis/results/17-nonlinear-J_EI_J_II-Jext32.pkl",
    "/home/alejandro/Proyectos/simulations/results/nonlinear_analysis/results/17-nonlinear-tau_syn_E-Jext32.pkl",
    "/home/alejandro/Proyectos/simulations/results/nonlinear_analysis/results/17-nonlinear-tau_syn_I-Jext32.pkl",
    "/home/alejandro/Proyectos/simulations/results/nonlinear_analysis/results/17-nonlinear-J_ext.pkl",
]

Jext2989_paths = [
    "/home/alejandro/Proyectos/simulations/results/nonlinear_analysis/results/17-nonlinear-J_EE_J_IE-Jext2989.pkl",
    "/home/alejandro/Proyectos/simulations/results/nonlinear_analysis/results/17-nonlinear-J_EI_J_II-Jext2989.pkl",
    "/home/alejandro/Proyectos/simulations/results/nonlinear_analysis/results/17-nonlinear-tau_syn_E-Jext2989.pkl",
    "/home/alejandro/Proyectos/simulations/results/nonlinear_analysis/results/17-nonlinear-tau_syn_I-Jext2989.pkl",
    "/home/alejandro/Proyectos/simulations/results/nonlinear_analysis/results/17-nonlinear-J_ext.pkl",
]

# %% [markdown]
# ## Results for J_ext = 32 nA

# %%
for result in Jext32_paths:
    df = pd.read_pickle(result)
    display(df)
# Out:
#    Parameter     Configuration   se_mean    se_std  \
# 0  J_EE_J_IE  (1.9237, 2.4444)  0.926704  0.014378
# 1  J_EE_J_IE  (1.6178, 2.0556)  0.955968  0.015629
# 2  J_EE_J_IE  (2.5359, 3.2222)  0.878488  0.011071
# 3  J_EE_J_IE     (0.3935, 0.5)  0.957502  0.012513
# 4  J_EE_J_IE  (0.6996, 0.8889)  0.965162  0.012802
# 5  J_EE_J_IE  (2.8419, 3.6111)  0.846624  0.012278
# 6  J_EE_J_IE  (1.3117, 1.6667)  0.959731  0.011086
# 7  J_EE_J_IE  (2.2298, 2.8333)  0.901457  0.012751
# 8  J_EE_J_IE      (3.148, 4.0)  0.806777  0.008812
# 9  J_EE_J_IE  (1.0056, 1.2778)  0.968126  0.012554
#
#                                               se_all  ctm_mean   ctm_std  \
# 0  [[0.9249287043962936, 0.9174343843166436, 0.93...  0.905652  0.014555
# 1  [[0.9680917271086176, 0.9398269018104684, 0.93...  0.937949  0.010233
# 2  [[0.8785004616488147, 0.8987448864081652, 0.87...  0.842478  0.015410
# 3  [[0.9720019163309275, 0.9479544953335596, 0.94...  0.985160  0.010077
# ...

# %%
def process_file(path):
    df = pd.read_pickle(path)
    result = pd.DataFrame({
        'ID': df['Parameter'],
        'Group': df['Configuration'],
        'SE_mean': df['se_mean'],
        'SE_std': df['se_std'],
        'CTM_mean': df['ctm_mean'],
        'CTM_std': df['ctm_std'],
    })
    return result


def process_all_files(paths):
    dfs = [process_file(path) for path in paths]
    return pd.concat(dfs, ignore_index=True)

# %%
df_jext32 = process_all_files(Jext32_paths)
df_jext32
# Out:
#            ID                Group   SE_mean    SE_std  CTM_mean   CTM_std
# 0   J_EE_J_IE     (1.9237, 2.4444)  0.926704  0.014378  0.905652  0.014555
# 1   J_EE_J_IE     (1.6178, 2.0556)  0.955968  0.015629  0.937949  0.010233
# 2   J_EE_J_IE     (2.5359, 3.2222)  0.878488  0.011071  0.842478  0.015410
# 3   J_EE_J_IE        (0.3935, 0.5)  0.957502  0.012513  0.985160  0.010077
# 4   J_EE_J_IE     (0.6996, 0.8889)  0.965162  0.012802  0.978715  0.007482
# 5   J_EE_J_IE     (2.8419, 3.6111)  0.846624  0.012278  0.790394  0.029134
# 6   J_EE_J_IE     (1.3117, 1.6667)  0.959731  0.011086  0.951449  0.008685
# 7   J_EE_J_IE     (2.2298, 2.8333)  0.901457  0.012751  0.878752  0.012309
# 8   J_EE_J_IE         (3.148, 4.0)  0.806777  0.008812  0.725565  0.025152
# 9   J_EE_J_IE     (1.0056, 1.2778)  0.968126  0.012554  0.966453  0.015442
# 10  J_EI_J_II   (-22.6667, -8.024)  0.947831  0.020412  0.934442  0.014471
# ...

# %%
def plot_results(df):
    features = ['SE', 'CTM']
    params = df['ID'].unique()
    n_params = len(params)

    fig, axes = plt.subplots(len(features), n_params, figsize=(5 * n_params, 4 * len(features)), squeeze=False)

    for col, param in enumerate(params):
        param_df = df[df['ID'] == param].copy()
        # Ordenar por valor absoluto del Group (soporta tuplas y escalares)
        param_df['_sort_key'] = param_df['Group'].apply(
            lambda g: tuple(abs(v) for v in g) if isinstance(g, tuple) else abs(g)
        )
        param_df = param_df.sort_values('_sort_key')
        x = range(len(param_df))
        labels = [str(g) for g in param_df['Group']]

        for row, feat in enumerate(features):
            ax = axes[row, col]
            mean = param_df[f'{feat}_mean']
            std = param_df[f'{feat}_std']

            ax.plot(list(x), mean.values, marker='o')
            ax.fill_between(list(x), (mean - std).values, (mean + std).values, alpha=0.3)
            ax.set_xticks(list(x))
            ax.set_xticklabels(labels, rotation=45, ha='right', fontsize=8)

            if col == 0:
                ax.set_ylabel(feat)
            if row == 0:
                ax.set_title(param)

    fig.tight_layout()
    return fig

# %%
fig_jext32 = plot_results(df_jext32)

# %%
df_jext2989 = process_all_files(Jext2989_paths)
df_jext2989
# Out:
#            ID                Group   SE_mean    SE_std  CTM_mean   CTM_std
# 0   J_EE_J_IE        (0.3935, 0.5)  0.920017  0.016462  0.994028  0.003311
# 1   J_EE_J_IE     (0.6996, 0.8889)  0.922352  0.009671  0.990682  0.005369
# 2   J_EE_J_IE     (1.9237, 2.4444)  0.933477  0.010004  0.959579  0.005659
# 3   J_EE_J_IE         (3.148, 4.0)  0.904858  0.007801  0.892161  0.016152
# 4   J_EE_J_IE     (2.8419, 3.6111)  0.905757  0.015034  0.916327  0.015447
# 5   J_EE_J_IE     (1.6178, 2.0556)  0.932909  0.010852  0.970877  0.008320
# 6   J_EE_J_IE     (2.5359, 3.2222)  0.909392  0.014914  0.924422  0.024783
# 7   J_EE_J_IE     (1.0056, 1.2778)  0.931012  0.020297  0.983460  0.010456
# 8   J_EE_J_IE     (1.3117, 1.6667)  0.932568  0.010058  0.976628  0.006109
# 9   J_EE_J_IE     (2.2298, 2.8333)  0.923033  0.010971  0.946832  0.006544
# 10  J_EI_J_II      (-14.0, -4.956)  0.915581  0.010601  0.982469  0.004904
# ...

# %%
fig_jext2989 = plot_results(df_jext2989)
